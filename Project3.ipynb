# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_test=pd.read_csv('test.csv')
df_train=pd.read_csv('train.csv')

# %%
df_train['species']
# Out:
# 0                Acer_Opalus
# 1      Pterocarya_Stenoptera
# 2       Quercus_Hartwissiana
# 3            Tilia_Tomentosa
# 4         Quercus_Variabilis
#                ...
# 985     Magnolia_Salicifolia
# 986              Acer_Pictum
# 987       Alnus_Maximowiczii
# 988            Quercus_Rubra
# 989           Quercus_Afares
# Name: species, Length: 990, dtype: object

# %%
from sklearn import preprocessing

label_encoder=preprocessing.LabelEncoder()

df_train['species']=label_encoder.fit_transform(df_train['species'])

df_train['species'].unique()
# Out:
# array([ 3, 49, 65, 94, 84, 40, 54, 78, 53, 89, 98, 16, 74, 50, 58, 31, 43,
#         4, 75, 44, 83, 13, 66, 15,  6, 73, 22, 36, 27, 88, 12, 28, 21, 25,
#        20, 60, 69, 23, 76, 18, 52,  9, 48, 47, 64, 81, 62, 34, 92, 79, 82,
#        32, 35, 72, 71, 11, 51,  5,  8, 37, 97, 33,  1, 59, 56, 57, 29, 93,
#        10, 46,  0, 39,  2, 24, 26, 87, 55, 38, 45,  7, 67, 30, 61, 96, 41,
#        85, 14, 17, 42, 63, 86, 80, 77, 19, 95, 70, 90, 68, 91])

# %%
y=df_train.iloc[:,1].values
x=df_train.iloc[:,2:].values

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=.2,random_state=0)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import accuracy_score

regressor = RandomForestRegressor(n_estimators=25, random_state=0)
regressor.fit(xtrain, ytrain)
ypred = regressor.predict(xtest)

print('Random_Forest score=',regressor.score(xtest,ytest))
# Out:
# Random_Forest score= 0.66925786862019

# %%
from sklearn.svm import SVC
clf=SVC(kernel='rbf',C=1e9,gamma=1e-07,probability=True)
clf.fit(xtrain,ytrain)
ypred=clf.predict(xtest)
print('SVC =',accuracy_score(ypred,ytest))
# Out:
# SVC = 0.7323232323232324

# %%
from sklearn.naive_bayes import GaussianNB
gnb=GaussianNB()
gnb.fit(xtrain,ytrain)
ypred=gnb.predict(xtest)
print('Navie Bayes Score',accuracy_score(ypred,ytest))
# Out:
# Navie Bayes Score 0.4696969696969697

# %%
from sklearn.tree import DecisionTreeClassifier
dtc=DecisionTreeClassifier()
dtc.fit(xtrain,ytrain)
ypred=dtc.predict(xtest)
print('Decision Tree Classifer',accuracy_score(ypred,ytest))
# Out:
# Decision Tree Classifer 0.5757575757575758

# %% [markdown]
# # classifier which has the best accuracy is Support Vector Classifier

# %%
df_test
# Out:
#        id   margin1   margin2   margin3   margin4   margin5   margin6  \
# 0       4  0.019531  0.009766  0.078125  0.011719  0.003906  0.015625
# 1       7  0.007812  0.005859  0.064453  0.009766  0.003906  0.013672
# 2       9  0.000000  0.000000  0.001953  0.021484  0.041016  0.000000
# 3      12  0.000000  0.000000  0.009766  0.011719  0.017578  0.000000
# 4      13  0.001953  0.000000  0.015625  0.009766  0.039062  0.000000
# ..    ...       ...       ...       ...       ...       ...       ...
# 589  1576  0.000000  0.000000  0.003906  0.015625  0.041016  0.000000
# 590  1577  0.000000  0.003906  0.003906  0.005859  0.017578  0.000000
# 591  1579  0.017578  0.029297  0.015625  0.013672  0.003906  0.015625
# 592  1580  0.013672  0.009766  0.060547  0.025391  0.035156  0.025391
# 593  1583  0.000000  0.117190  0.000000  0.019531  0.000000  0.136720
#
#       margin7   margin8   margin9  ...  texture55  texture56  texture57  \
# ...

# %%
xtest=df_test.iloc[:,1:].values

# %%
ypred=clf.predict(xtest)

# %%
print(ypred)
# Out:
# [51 50  1 19 14 83  3 29 84  8 43 74 75 94 52 53 45 68 86 71 61 54 57 77
#   1 70 28 15 35 70 53 74 19 50  4 67 14 55 39 93  8 32  8  9 71 70 38 23
#  48 18 86  5 55 94 14 86 67 33 51 54 88 56 87 59 65 11 48  5 11  4 54 57
#  29 17 68 98 92 84 25 10 61 43 85 24  1 68 23 46 39 22 48 90 25 68 37 56
#  41 95  7 48 98 77  3 12 68 84 53 96 64 72 93 93 67 67  8 88 60 87  6 57
#  33 90 60 17 86 66 51  7 39 23 96 72 41 61 24 97 29 29 68 81 68 51 53 62
#  60 52 95  3 42 96 95 20 59 35 86  1 56 38 43 75 20 60 46 79 22 79 50 87
#  65 97 75 21 37 67 11 68 58 94 27 22 15 45 58 54 43  5 23 94 25  7 11 72
#  36 11 51 95 18 91 29 64 80  6 78 45 87  9 78 90 27 11 92 95 35 59  0 96
#  70 32 29 78 91 51 27 38  5 62 48 92 93 67 17 67 90 39 25 37 18  0 76 44
#  70 71 27 70 32 96 30 82 33 39 82 96 48 65 17 64 56 53 55 58  9 83 83 41
#  29 63 11 22 67 63 12 78 36 14 27 25 67 38 20 54 76 56 67 97 80 44 92 50
#  23 21 94 51 33 77 16 11 97  1 52 39 24 52 42 52  2 73 43 83 67  9 63 53
# ...
